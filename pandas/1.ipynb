# %%
import numpy as np
import pandas as pd

file_path = "/home/veronica/Downloads/Python/python_practice/pandas/emp.xlsx"

# %%
df = pd.read_excel(file_path)

df
# Out:
#     FirstName MiddleName           LastName                      JobTitle  \
# 0      Maciej          W              Dusza  Production Technician - WC60
# 1     Michael          J           Zwilling  Production Technician - WC60
# 2       Randy          T             Reeves  Production Technician - WC60
# 3       Karan          R             Khanna  Production Technician - WC60
# 4         Jay          G              Adams  Production Technician - WC60
# ..        ...        ...                ...                           ...
# 285      Lynn          N           Tsoflias          Sales Representative
# 286       Amy          E            Alberts        European Sales Manager
# 287    Rachel          B             Valdez          Sales Representative
# 288       Jae          B                Pak          Sales Representative
# 289    Ranjit          R  Varkey Chudukatil          Sales Representative
#
#       HireDate                  EmailAddress          PhoneNumber
# ...

# %%
df.loc[0:2, ["FirstName", "LastName","JobTitle"]]
# Out:
#   FirstName  LastName                      JobTitle
# 0    Maciej     Dusza  Production Technician - WC60
# 1   Michael  Zwilling  Production Technician - WC60
# 2     Randy    Reeves  Production Technician - WC60

# %%
df.loc[df["JobTitle"]=="Production Technician - WC60"]
# Out:
#    FirstName MiddleName     LastName                      JobTitle   HireDate  \
# 0     Maciej          W        Dusza  Production Technician - WC60 2010-01-29
# 1    Michael          J     Zwilling  Production Technician - WC60 2010-02-23
# 2      Randy          T       Reeves  Production Technician - WC60 2010-02-23
# 3      Karan          R       Khanna  Production Technician - WC60 2009-12-22
# 4        Jay          G        Adams  Production Technician - WC60 2009-03-05
# 5    Charles          B   Fitzgerald  Production Technician - WC60 2009-12-03
# 6      Steve          F      Masters  Production Technician - WC60 2009-02-15
# 7      David          J        Ortiz  Production Technician - WC60 2008-12-15
# 48    Eugene          O        Kogan  Production Technician - WC60 2009-02-08
# 49    Thomas          R     Michaels  Production Technician - WC60 2009-02-26
# 50     Simon          D       Rapier  Production Technician - WC60 2008-12-08
# ...
